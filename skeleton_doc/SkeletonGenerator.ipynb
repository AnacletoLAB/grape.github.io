# %%
import re
import os
import inspect
import json
from pprint import pprint
from glob import glob
import shutil
from tqdm.auto import tqdm

# %%
import grape

# %%
BLACKLIST = [
    "OptimizerV2"
]

# %%
def explore_python(root, module):
    # Hardcoded are safe TODO: decomment, apparenty they arent :)
    if False and getattr(root, "__all__", None) is not None:
        return {
            getattr(root, x)
            for x in root.__all__
        }
    
    return {
        getattr(root, x) 
        for x in dir(root)
        if not x.startswith("_") 
            and (
                inspect.isfunction(getattr(root, x))
                or inspect.isclass(getattr(root, x)) 
                or inspect.ismodule(getattr(root, x))
            ) and (
                module.__name__ == "grape"
                or
                module.__name__ in inspect.getmodule(getattr(root, x)).__name__
            ) and 
            not inspect.isbuiltin(getattr(root, x))
    }

def recursive_explore_python(root):
    if inspect.isfunction(root) or inspect.isclass(root):
        return {root}
    
    return {
        y
        for x in explore_python(root, root)
        for y in recursive_explore_python(x)
    }

# %%
def explore_on_level(module, root):
    return {
        os.path.join(*root, x) + ".py":getattr(module, x)
        for x in dir(module)
        if not x.startswith("_")
    }

# %%
def tabbify(string):
    return "\n".join(
        "    " + x
        for x in string.split("\n")
    )

def safe_list_get(l, idx):
    if l is None:
        return None
    try:
        return str(l[idx])
    except IndexError:
        return None

# %%
def handle_class_builtin(klass) -> str:
    return """
class {class_name}:
    \"\"\"{doc}\"\"\"
{methods}
    """.format(
        class_name=klass.__name__,
        doc=klass.__doc__ or "TODO!: document this",
        methods=tabbify("\n\n".join(
            handle_function_builtin(getattr(klass, x))
            for x in dir(klass)
            if not x.startswith("_")
        )),
    )

import re
def handle_function_builtin(function) -> str:
    args = []
    arg_names = inspect.getfullargspec(function).args
    if "self" in arg_names:
        args.append("self")
    if function.__doc__ is None:
        print('Function %s miss documentation'%function.__name__)
    for line in (function.__doc__ or "").split("\n"):
        if ":" not in line:
            continue
        
        arg_name, _, line = line.partition(":")
        
        if arg_name not in arg_names:
            continue
        
        line = line.strip().strip(",")
        # add auto-defaults for optionals to None if there isn't already one
        if line.startswith("Optional") and "=" not in line:
            line += " = None"
            
        result = "{}: {}".format(
            arg_name,
            line
        )
        args.append(result)
    
    return """
def {function_name}({args}):
    \"\"\"{doc}\"\"\"
""".format(
        function_name=function.__name__,
        doc=tabbify(function.__doc__ or "TODO!: document").strip(),
        args=", ".join(args),
    )

# %%
def handle_class(klass) -> str:
    return """
class {class_name}({extensions}):
    \"\"\"{doc}\"\"\"
{properties}
{methods}
    """.format(
        class_name=klass.__name__,
        doc=klass.__doc__ or "TODO!: document",
        properties=tabbify("\n\n".join(
            handle_property(x, getattr(klass, x))
            for x in dir(klass)
            if not x.startswith("_") and type(getattr(klass, x)) == property
        )),
        methods=tabbify("\n\n".join(
            handle_function(getattr(klass, x))
            for x in dir(klass)
            if not x.startswith("_") and type(getattr(klass, x)) != property and
            inspect.ismethod(getattr(klass, x))
        )),
        extensions=", ".join(
            x.__name__.replace("embiggen", "grape")
            for x in inspect.getmro(klass)
            if x.__name__ != "object"
        ),
    )

def handle_property(name, function) -> str:
    return """
@property
def {function_name}(self):
    \"\"\"{doc}\"\"\"
""".format(
        function_name=name,
        doc=function.__doc__ or "TODO!: document",
    )
    
    
def handle_function(function) -> str:
    info = inspect.getfullargspec(function)
    args = []
    for (i, arg_name) in enumerate(info.args):
        if arg_name == "self":
            args.append("self")
            continue
            
        result = arg_name
        
        arg_type = getattr(info.annotations.get(arg_name), "__name__", str(info.annotations.get(arg_name)))
        if arg_type is not None:
            if str(arg_type) in BLACKLIST:
                arg_type = '"%s"'%arg_type
            result += ": {}".format(arg_type)
         
        # TODO! figure out how to property do defaults
        # Their order is not trivial (I think that they start form the end)
        #default = safe_list_get(info.defaults, i)
        
        #if default is not None:
        #    result += "= {}".format(default)
            
        args.append(result)
    
    return_annotation = ""
    return_type = info.annotations.get("return")
    if return_type is not None:
        try:
            return_annotation += " -> {}".format(return_type.__name__)
        except AttributeError:
            return_annotation += " -> {}".format(return_type._name)
        
    
    return """
def {function_name}({args}){return_annotation}:
    \"\"\"{doc}\"\"\"
""".format(
        function_name=function.__name__,
        doc=function.__doc__ or "TODO!: document this",
        args=", ".join(args),
        return_annotation=return_annotation,
    )

# %%
def imports(f):
    f.write("import typing\n")
    f.write("from typing import *\n")
    f.write("from tensorflow import Tensor, SparseTensor\n") 
    f.write("from ensmallen import Graph\n")

# %%
def build_file_python(path: str, my_object):
    """Write to disk the documentation of the given method or class."""
    directory_path = os.path.dirname(path)
    
    os.makedirs(directory_path, exist_ok=True)
    init_path = os.path.join(directory_path, "__init__.py")
    
    if os.path.exists(init_path):
        with open(init_path, "r") as f:
            init = f.read()
    else:
        init = ""
        
    current_import = "from .{} import *\n".format(os.path.basename(path).replace(".py", ""))
    if current_import not in init:
        init += current_import
        
    for folder in os.listdir(directory_path):
        if "." in folder:
            continue 
            
        import_line = "from . import {}\n".format(folder)
        if import_line not in init:
            init += import_line
        
    with open(init_path, "w") as f:
        f.write(init)

    if inspect.isclass(my_object):
        content = handle_class(my_object)
    else:
        content = handle_function(my_object)
        
    with open(path, "w") as f:
        imports(f)
        f.write(content)

# %%
def build_file_builtin(path: str, my_object):
    """Write to disk the documentation of the given method or class."""
    directory_path = os.path.dirname(path)
    
    os.makedirs(directory_path, exist_ok=True)
    init_path = os.path.join(directory_path, "__init__.py")
    
    if os.path.exists(init_path):
        with open(init_path, "r") as f:
            init = f.read()
    else:
        init = ""
        
    current_import = "from .{} import *\n".format(os.path.basename(path).replace(".py", ""))
    if current_import not in init:
        init += current_import
        
    for folder in os.listdir(directory_path):
        if "." in folder:
            continue 
            
        import_line = "from . import {}\n".format(folder)
        if import_line not in init:
            init += import_line
        
    with open(init_path, "w") as f:
        f.write(init)

    if inspect.isclass(my_object):
        content = handle_class_builtin(my_object)
    else:
        content = handle_function_builtin(my_object)
        
    with open(path, "w") as f:
        imports(f)
        f.write(content)

# %%
def setup_init_files():
    dirs = [   path
        for path in glob(os.path.join(*ROOT, "**"), recursive=True)
        if os.path.isdir(path)
    ]
    for path in dirs:
        init_path = os.path.join(path, "__init__.py")
        if os.path.exists(init_path):
            continue

        with open(init_path, "w") as f:

            for folder in os.listdir(path):

                if os.path.isdir(os.path.join(path, folder)):
                    f.write("from . import {}\n".format(folder))
                else:
                    print("skipped", folder)
                    continue

# %%
ROOT = ["skeleton_package", "grape"]

# %%
dir(grape)
# Out:
# ['EmbeddingResult',
#  'Graph',
#  'GraphVisualizer',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'datasets',
#  'edge_label_prediction',
#  'edge_prediction',
#  'embedders',
#  'embedding_transformers',
#  'get_available_models_for_edge_label_prediction',
#  'get_available_models_for_edge_prediction',
#  'get_available_models_for_node_embedding',
#  'get_available_models_for_node_label_prediction',
#  'get_models_dataframe',
#  'layers',
#  'node_label_prediction',
#  'sequences',
#  'utils',
#  'visualizations']

# %%
python_stuff = {
    os.path.join(
        *ROOT,
        *inspect.getmodule(v).__name__.split("."), 
        v.__name__
    ) + ".py":v
    for v in recursive_explore_python(grape)
}

# %%
rust_stuff = {
    os.path.join(*ROOT, "graph.py"):grape.Graph,
    #os.path.join(*ROOT, "djkstra.py"):ensmallen,
    #os.path.join(*ROOT, "bfs.py"):grape.ShortestPathsResultBFS,
    #**explore_on_level(ensmallen.edge_list_utils, [*ROOT, "ensmallen", "edge_list_utils"]),
    #**explore_on_level(ensmallen.preprocessing, [*ROOT, "ensmallen", "preprocessing"]),
}

# %%
python_stuff
# Out:
# {'skeleton_package/grape/datasets/string/CorynebacteriumSpHmsc04h06.py': <function datasets.string.CorynebacteriumSpHmsc04h06(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/MicrobacteriumSpCgr1.py': <function datasets.string.MicrobacteriumSpCgr1(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/MethanosarcinaSpMtp4Cluster.py': <function datasets.string.MethanosarcinaSpMtp4Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/BdellovibrionalesBacteriumGwa24915Cluster.py': <function datasets.string.BdellovibrionalesBacteriumGwa24915Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/PsychrobacterPhenylpyruvicusCluster.py': <function datasets.string.PsychrobacterPhenylpyruvicusCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/AcinetobacterSpAnc4470Cluster.py': <function datasets.string.AcinetobacterSpAnc4470Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ArthrobacterCupressiCluster.py': <function datasets.string.ArthrobacterCupressiCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/StreptomycesSpYr375.py': <function datasets.string.StreptomycesSpYr375(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ElusimicrobiaBacteriumRifoxya2Full4753.py': <function datasets.string.ElusimicrobiaBacteriumRifoxya2Full4753(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/VibrioParahaemolyticus.py': <function datasets.string.VibrioParahaemolyticus(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/HalonatronumSaccharophilumCluster.py': <function datasets.string.HalonatronumSaccharophilumCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ClostridiumSpCag492Cluster.py': <function datasets.string.ClostridiumSpCag492Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/StreptococcusUrinalisFb127cna2.py': <function datasets.string.StreptococcusUrinalisFb127cna2(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/AfipiaSpRoot123d2.py': <function datasets.string.AfipiaSpRoot123d2(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/PhenylobacteriumSpRoot700.py': <function datasets.string.PhenylobacteriumSpRoot700(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/LysobacterCapsici.py': <function datasets.string.LysobacterCapsici(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/WenxiniaSaemankumensis.py': <function datasets.string.WenxiniaSaemankumensis(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/AncylostomaCeylanicumCluster.py': <function datasets.string.AncylostomaCeylanicumCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/CollinsellaSpMs5Cluster.py': <function datasets.string.CollinsellaSpMs5Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/AeromicrobiumSpLeaf291Cluster.py': <function datasets.string.AeromicrobiumSpLeaf291Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ParacoccusHomiensis.py': <function datasets.string.ParacoccusHomiensis(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/HalobacteriumJilantaienseCluster.py': <function datasets.string.HalobacteriumJilantaienseCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/MaribacterForsetii.py': <function datasets.string.MaribacterForsetii(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/MethanobacteriumSpMaddingleyCluster.py': <function datasets.string.MethanobacteriumSpMaddingleyCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/CandidatusYanofskybacteriaBacteriumRifcsplowo201Full4422Cluster.py': <function datasets.string.CandidatusYanofskybacteriaBacteriumRifcsplowo201Full4422Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ErythrobacterSpSd21.py': <function datasets.string.ErythrobacterSpSd21(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/HistoplasmaCapsulatumNam1Cluster.py': <function datasets.string.HistoplasmaCapsulatumNam1Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/AlistipesSenegalensisCluster.py': <function datasets.string.AlistipesSenegalensisCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/BradyrhizobiumSpWsm1253.py': <function datasets.string.BradyrhizobiumSpWsm1253(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ChaetomiumThermophilumVarThermophilumDsm1495.py': <function datasets.string.ChaetomiumThermophilumVarThermophilumDsm1495(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/PolyporusArculariusHhb13444Cluster.py': <function datasets.string.PolyporusArculariusHhb13444Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ArthrobotrysFlagrans.py': <function datasets.string.ArthrobotrysFlagrans(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ChitinophagaArvensicola.py': <function datasets.string.ChitinophagaArvensicola(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/StreptococcusMitisAtcc6249Cluster.py': <function datasets.string.StreptococcusMitisAtcc6249Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/FonsecaeaMultimorphosaCbs102226Cluster.py': <function datasets.string.FonsecaeaMultimorphosaCbs102226Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/HerbaspirillumSpYr522.py': <function datasets.string.HerbaspirillumSpYr522(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/PaenibacillusSpSoil750.py': <function datasets.string.PaenibacillusSpSoil750(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/CollinsellaVaginalis.py': <function datasets.string.CollinsellaVaginalis(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ParacoccusSpPamc22219Cluster.py': <function datasets.string.ParacoccusSpPamc22219Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/PelotomaculumSpDtu098Cluster.py': <function datasets.string.PelotomaculumSpDtu098Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/AcinetobacterSpAnc4470.py': <function datasets.string.AcinetobacterSpAnc4470(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/PaenibacillusSpTca20Cluster.py': <function datasets.string.PaenibacillusSpTca20Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/TrichophytonRubrumCbs118892Cluster.py': <function datasets.string.TrichophytonRubrumCbs118892Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/BacillusSpJ37Cluster.py': <function datasets.string.BacillusSpJ37Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/DeltaproteobacteriaBacteriumRifoxyd12Full5712Cluster.py': <function datasets.string.DeltaproteobacteriaBacteriumRifoxyd12Full5712Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/RhodopseudomonasPalustrisCga009.py': <function datasets.string.RhodopseudomonasPalustrisCga009(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/AkkermansiaMuciniphilaCluster.py': <function datasets.string.AkkermansiaMuciniphilaCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/NeisseriaLactamica.py': <function datasets.string.NeisseriaLactamica(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/PundamiliaNyerereiCluster.py': <function datasets.string.PundamiliaNyerereiCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/MycobacteriumSpKms.py': <function datasets.string.MycobacteriumSpKms(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/PseudovibrioAscidiaceicolaCluster.py': <function datasets.string.PseudovibrioAscidiaceicolaCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/SpinaciaOleraceaCluster.py': <function datasets.string.SpinaciaOleraceaCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/BosMutusCluster.py': <function datasets.string.BosMutusCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/HaloferacaceaeArchaeonB1Br10E2g22Cluster.py': <function datasets.string.HaloferacaceaeArchaeonB1Br10E2g22Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/MucilaginibacterPolytrichastriCluster.py': <function datasets.string.MucilaginibacterPolytrichastriCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/HaloquadratumWalsbyiJ07hqw2Cluster.py': <function datasets.string.HaloquadratumWalsbyiJ07hqw2Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/MetallosphaeraSedulaCluster.py': <function datasets.string.MetallosphaeraSedulaCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/UnicellularCyanobacteriumSu2Cluster.py': <function datasets.string.UnicellularCyanobacteriumSu2Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/MesocricetusAuratus.py': <function datasets.string.MesocricetusAuratus(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/PaenibacillusMacerans.py': <function datasets.string.PaenibacillusMacerans(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ThiothrixCaldifontisCluster.py': <function datasets.string.ThiothrixCaldifontisCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/BesnoitiaBesnoitiCluster.py': <function datasets.string.BesnoitiaBesnoitiCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/BifidobacteriumMinimumCluster.py': <function datasets.string.BifidobacteriumMinimumCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/PseudomonasSpAnt303Cluster.py': <function datasets.string.PseudomonasSpAnt303Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/CandidaGlabrata.py': <function datasets.string.CandidaGlabrata(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/MethanobrevibacterRuminantium.py': <function datasets.string.MethanobrevibacterRuminantium(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/StreptococcusSpVt162.py': <function datasets.string.StreptococcusSpVt162(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ComamonasTerrigenaNbrc13299.py': <function datasets.string.ComamonasTerrigenaNbrc13299(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/DenitrovibrioAcetiphilusCluster.py': <function datasets.string.DenitrovibrioAcetiphilusCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/PenicilliumDigitatumPhi26Cluster.py': <function datasets.string.PenicilliumDigitatumPhi26Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/AncylostomaCaninum.py': <function datasets.string.AncylostomaCaninum(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/CandidatusKryptobacterTengchongensis.py': <function datasets.string.CandidatusKryptobacterTengchongensis(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/PapillibacterCinnamivoransDsm12816Cluster.py': <function datasets.string.PapillibacterCinnamivoransDsm12816Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/CandidatusAzambacteriaBacteriumRifoxyb1Full4033.py': <function datasets.string.CandidatusAzambacteriaBacteriumRifoxyb1Full4033(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/DevosiaPsychrophila.py': <function datasets.string.DevosiaPsychrophila(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/SedimentitaleaNanhaiensisCluster.py': <function datasets.string.SedimentitaleaNanhaiensisCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/MethylophilalesBacteriumLsucc0135.py': <function datasets.string.MethylophilalesBacteriumLsucc0135(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/NatrialbaAsiaticaCluster.py': <function datasets.string.NatrialbaAsiaticaCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/StreptococcusMitis2Sk95Cluster.py': <function datasets.string.StreptococcusMitis2Sk95Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/CastorCanadensisCluster.py': <function datasets.string.CastorCanadensisCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ChelativoransSpBnc1Cluster.py': <function datasets.string.ChelativoransSpBnc1Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/GemellaCuniculiCluster.py': <function datasets.string.GemellaCuniculiCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ClostridiumSpL250.py': <function datasets.string.ClostridiumSpL250(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/OmnitrophicaWor2BacteriumGwa24518Cluster.py': <function datasets.string.OmnitrophicaWor2BacteriumGwa24518Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/OpitutaceaeBacteriumTsb47.py': <function datasets.string.OpitutaceaeBacteriumTsb47(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/DiaphorinaCitri.py': <function datasets.string.DiaphorinaCitri(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/GammaproteobacteriaBacteriumHimb55Cluster.py': <function datasets.string.GammaproteobacteriaBacteriumHimb55Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.0', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/LoktanellaSpDsm29012.py': <function datasets.string.LoktanellaSpDsm29012(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/BrachyspiraMurdochii.py': <function datasets.string.BrachyspiraMurdochii(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/NitrospiraeBacteriumCg10244142.py': <function datasets.string.NitrospiraeBacteriumCg10244142(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/RubidibacterLacunae.py': <function datasets.string.RubidibacterLacunae(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/MycoplasmaPenetrans.py': <function datasets.string.MycoplasmaPenetrans(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ThermusAntranikianiiCluster.py': <function datasets.string.ThermusAntranikianiiCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/VibrioPalustrisCluster.py': <function datasets.string.VibrioPalustrisCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/DevosiaRiboflavinaCluster.py': <function datasets.string.DevosiaRiboflavinaCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/MethyloteneraVersatilis7.py': <function datasets.string.MethyloteneraVersatilis7(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/PseudoalteromonasPrydzensis.py': <function datasets.string.PseudoalteromonasPrydzensis(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/AeromonasAquaticaCluster.py': <function datasets.string.AeromonasAquaticaCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/FlavobacteriumSp316.py': <function datasets.string.FlavobacteriumSp316(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/OpitutaceaeBacteriumTsb47Cluster.py': <function datasets.string.OpitutaceaeBacteriumTsb47Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/CandidatusLloydbacteriaBacteriumRifcsplowo202Full5111Cluster.py': <function datasets.string.CandidatusLloydbacteriaBacteriumRifcsplowo202Full5111Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/LactobacillusComposti.py': <function datasets.string.LactobacillusComposti(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/PseudovibrioSpFobeg1Cluster.py': <function datasets.string.PseudovibrioSpFobeg1Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/MethylobacteriumSp10.py': <function datasets.string.MethylobacteriumSp10(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/RhodobacterSpCacia14h1.py': <function datasets.string.RhodobacterSpCacia14h1(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/VitellibacterAquimarisCluster.py': <function datasets.string.VitellibacterAquimarisCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/CandidatusLiptonbacteriaBacteriumRifcsplowo201Full5225Cluster.py': <function datasets.string.CandidatusLiptonbacteriaBacteriumRifcsplowo201Full5225Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/CandidatusRyanbacteriaBacteriumRifcsplowo202Full4714.py': <function datasets.string.CandidatusRyanbacteriaBacteriumRifcsplowo202Full4714(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/DesulfuromonadaceaeBacteriumGwc25813Cluster.py': <function datasets.string.DesulfuromonadaceaeBacteriumGwc25813Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/PseudomonasSpS9Cluster.py': <function datasets.string.PseudomonasSpS9Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/FischerellaMuscicola.py': <function datasets.string.FischerellaMuscicola(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/MicrobulbiferAgarilyticus.py': <function datasets.string.MicrobulbiferAgarilyticus(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/MarinimicrobiumAgarilyticum.py': <function datasets.string.MarinimicrobiumAgarilyticum(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/TrametesPubescens.py': <function datasets.string.TrametesPubescens(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/DuganellaSpLeaf126Cluster.py': <function datasets.string.DuganellaSpLeaf126Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/AgromycesItalicusCluster.py': <function datasets.string.AgromycesItalicusCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/CandidatusBerkiellaCookevillensis.py': <function datasets.string.CandidatusBerkiellaCookevillensis(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ThielaviaTerrestris.py': <function datasets.string.ThielaviaTerrestris(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/CandidatusAdlerbacteriaBacteriumRifoxyc1Full4826.py': <function datasets.string.CandidatusAdlerbacteriaBacteriumRifoxyc1Full4826(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/OpitutaceaeBacteriumTav4Cluster.py': <function datasets.string.OpitutaceaeBacteriumTav4Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ActinomaduraHibiscaNbrc15177Cluster.py': <function datasets.string.ActinomaduraHibiscaNbrc15177Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ThermoplasmatalesArchaeonAPlasma.py': <function datasets.string.ThermoplasmatalesArchaeonAPlasma(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
# ...
#  'skeleton_package/grape/datasets/string/RhizobacterSpRoot29Cluster.py': <function datasets.string.RhizobacterSpRoot29Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/AnaplasmaMarginaleFloridaCluster.py': <function datasets.string.AnaplasmaMarginaleFloridaCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ChryseobacteriumAquaticum.py': <function datasets.string.ChryseobacteriumAquaticum(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ProteusPenneriCluster.py': <function datasets.string.ProteusPenneriCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/BdellovibrioExovorus.py': <function datasets.string.BdellovibrioExovorus(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/HathewayaProteolyticaDsm3090.py': <function datasets.string.HathewayaProteolyticaDsm3090(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/MoorellaSp6041.py': <function datasets.string.MoorellaSp6041(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/CorynebacteriumUlceransCluster.py': <function datasets.string.CorynebacteriumUlceransCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/GolovinomycesCichoracearum.py': <function datasets.string.GolovinomycesCichoracearum(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/StreptomycesSpCnr698.py': <function datasets.string.StreptomycesSpCnr698(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/AcetobacteriumBakiiCluster.py': <function datasets.string.AcetobacteriumBakiiCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/ClostridialesBacteriumKa00134Cluster.py': <function datasets.string.ClostridialesBacteriumKa00134Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/SynechococcusSpWh5701.py': <function datasets.string.SynechococcusSpWh5701(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/AcidovoraxSpRoot70Cluster.py': <function datasets.string.AcidovoraxSpRoot70Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/AspergillusOryzaeRib40Cluster.py': <function datasets.string.AspergillusOryzaeRib40Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/EctothiorhodospiraMagnaCluster.py': <function datasets.string.EctothiorhodospiraMagnaCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/BacteroidalesBacteriumH5.py': <function datasets.string.BacteroidalesBacteriumH5(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/SalariasFasciatus.py': <function datasets.string.SalariasFasciatus(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/SuccinatimonasHippei.py': <function datasets.string.SuccinatimonasHippei(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/BoseaSp117.py': <function datasets.string.BoseaSp117(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/PseudoalteromonasPiscicida.py': <function datasets.string.PseudoalteromonasPiscicida(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/PseudoalteromonasSp1315Cluster.py': <function datasets.string.PseudoalteromonasSp1315Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/MycolicibacteriumMoriokaenseCluster.py': <function datasets.string.MycolicibacteriumMoriokaenseCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/RodentibacterMrazii.py': <function datasets.string.RodentibacterMrazii(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/VeillonellaAtypicaKonCluster.py': <function datasets.string.VeillonellaAtypicaKonCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/BurkholderialesBacteriumJoshi001.py': <function datasets.string.BurkholderialesBacteriumJoshi001(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/NatrialbaceaeArchaeonTcBr11E2g28Cluster.py': <function datasets.string.NatrialbaceaeArchaeonTcBr11E2g28Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/NitratireductorIndicusCluster.py': <function datasets.string.NitratireductorIndicusCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/HalomonasCampaniensisCluster.py': <function datasets.string.HalomonasCampaniensisCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/LegionellaPneumophilaPhiladelphia.py': <function datasets.string.LegionellaPneumophilaPhiladelphia(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/RouxiellaBadensis.py': <function datasets.string.RouxiellaBadensis(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/BlastomonasSpCacia14h2.py': <function datasets.string.BlastomonasSpCacia14h2(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/NeisseriaCinerea.py': <function datasets.string.NeisseriaCinerea(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/NovosphingobiumMathurenseCluster.py': <function datasets.string.NovosphingobiumMathurenseCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/BacteroidesCaccae.py': <function datasets.string.BacteroidesCaccae(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/CandidatusThiodiazotrophaEndoloripes.py': <function datasets.string.CandidatusThiodiazotrophaEndoloripes(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/TersicoccusPhoenicisCluster.py': <function datasets.string.TersicoccusPhoenicisCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/CoccomyxaSubellipsoidea.py': <function datasets.string.CoccomyxaSubellipsoidea(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/PseudomonasWeihenstephanensis.py': <function datasets.string.PseudomonasWeihenstephanensis(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='links.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/SynechococcusSpBl107Cluster.py': <function datasets.string.SynechococcusSpBl107Cluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  'skeleton_package/grape/datasets/string/BrachypodiumDistachyonCluster.py': <function datasets.string.BrachypodiumDistachyonCluster(directed=False, preprocess='auto', load_nodes=True, load_node_types=True, load_edge_weights=True, auto_enable_tradeoffs=True, sort_tmp_dir=None, verbose=2, cache=True, cache_path=None, cache_sys_var='GRAPH_CACHE_DIR', version='cluster.v11.5', **kwargs) -> Graph>,
#  ...}

# %%
shutil.rmtree(ROOT[0])

for path, obj in tqdm(python_stuff.items()):
    build_file_python(path, obj)
# Out:
#   0%|          | 0/29800 [00:00<?, ?it/s]

# %%
for path, obj in tqdm(rust_stuff.items()):
    build_file_builtin(path, obj)
    
with open(os.path.join(ROOT[0], "setup.py"), "w") as f:
    f.write("""
from setuptools import find_packages, setup

setup(
    name='grape',
    version="1.0.0",
    packages=find_packages(exclude=['contrib', 'docs', 'tests*']),
)
""")
    
setup_init_files()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# skipped __init__.py
# skipped __init__.py
# skipped __init__.py
# skipped __init__.py
# skipped __init__.py
# skipped __init__.py
# skipped __init__.py
# skipped __init__.py
# skipped __init__.py
# skipped __init__.py
# skipped __init__.py
# skipped __init__.py
# skipped __init__.py
# skipped __init__.py
# skipped __init__.py
# skipped __init__.py
# skipped __init__.py
# skipped __init__.py
# skipped __init__.py
# skipped __init__.py

# %% [markdown]
# Making sphinx work:
# ```
# extensions = [
#     'sphinx.ext.autodoc',
#     'sphinx.ext.todo',
#     'sphinx.ext.mathjax',
#     'sphinx.ext.githubpages',
# ]
# ```
#
#
# [Reference](https://github.com/davidstutz/sphinx-example/blob/master/)

# %%
dir(grape)
# Out:
# ['EmbeddingResult',
#  'Graph',
#  'GraphVisualizer',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'datasets',
#  'edge_label_prediction',
#  'edge_prediction',
#  'embedders',
#  'embedding_transformers',
#  'get_available_models_for_edge_label_prediction',
#  'get_available_models_for_edge_prediction',
#  'get_available_models_for_node_embedding',
#  'get_available_models_for_node_label_prediction',
#  'get_models_dataframe',
#  'layers',
#  'node_label_prediction',
#  'sequences',
#  'utils',
#  'visualizations']
